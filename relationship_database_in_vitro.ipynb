# %%
# !! cd aryuna
import pandas as pd
# !!ls
df_sh_cmv = pd.read_csv('database_with_cmv/database_with_cmv.tsv', sep='\t')
print(df_sh_cmv)
# Out:
#       complex.id Gene                CDR3            V           J  \
# 0              0  TRB  CASSVDGTGGALGNTIYF     TRBV9*01  TRBJ1-3*01
# 1              0  TRB     CAWSWGDSTNSPLHF    TRBV30*01  TRBJ1-6*01
# 2              0  TRB   CASSLVGGTGSVSYQFF  TRBV11-2*01  TRBJ2-1*01
# 3              0  TRB     CASSLLMATNEKLFF    TRBV28*01  TRBJ1-4*01
# 4              0  TRB       CASSYRANYEQYF   TRBV7-9*01  TRBJ2-7*01
# 5              0  TRB  CASSQAVASGGGRSEQFF   TRBV3-1*01  TRBJ2-1*01
# 6              0  TRB       CASVTGSTDTQYF     TRBV2*01  TRBJ2-3*01
# 7              0  TRB       CASSDGTAYEQYF     TRBV2*01  TRBJ2-7*01
# 8              0  TRB       CASSLARNQPQHF   TRBV4-1*01  TRBJ1-5*01
# 9              0  TRB      CASGGADMKTEAFF    TRBV19*01  TRBJ1-1*01
# 10             0  TRB      CASSPGGGKETQYF   TRBV7-6*01  TRBJ2-5*01
# 11           144  TRB        CASSQDRDTQYF    TRBV14*01  TRBJ2-3*01
# 12           166  TRB     CASSPVTGGIYGYTF   TRBV6-5*01  TRBJ1-2*01
# 13           224  TRB      CASSQTQLWETQYF   TRBV7-2*02  TRBJ2-3*01
# 14           225  TRB    CASSLAPGTTNEKLFF   TRBV7-6*01  TRBJ1-4*01
# 15             0  TRB      CASSLFGGGTEAFF  TRBV12-3*01  TRBJ1-1*01
# 16             0  TRB     CASSPTGGGTGELFF    TRBV27*01  TRBJ2-2*01
# 17             0  TRB      CASSLGGGSYEQYF    TRBV13*01  TRBJ2-7*01
# 18             0  TRB      CASSLGGGSYEQYF    TRBV13*01  TRBJ2-7*01
# 19             0  TRB     CASSLGGGGFYEQYF   TRBV7-8*01  TRBJ2-7*01
# 20             0  TRB     CASSYGGGEDYGYTF    TRBV13*01  TRBJ1-2*01
# 21             0  TRB          CSGGTGELFF  TRBV29-1*01  TRBJ2-2*01
# 22             0  TRB        CSVGGTLDTQYF  TRBV29-1*01  TRBJ2-3*01
# 23             0  TRB      CASRDQTAYYGYTF  TRBV10-1*01  TRBJ1-2*01
# 24             0  TRB     CASSYQTGAAYGYTF   TRBV6-5*01  TRBJ1-2*01
# 25             0  TRB     CASSYQTGAIYGYTF   TRBV6-5*01  TRBJ1-2*01
# 26             0  TRB     CASSYQTGTIYGYTF   TRBV6-5*01  TRBJ1-2*01
# 27             0  TRB     CASSYQTGAAYGYTF   TRBV6-5*01  TRBJ1-2*01
# 28             0  TRB     CASSCQTGAACGYTF   TRBV6-5*01  TRBJ1-2*01
# 29             0  TRB    CASSLQTGVRSYEQYF   TRBV6-5*01  TRBJ2-7*01
# ...          ...  ...                 ...          ...         ...
# 5908        3962  TRA         CASNTGNQFYF    TRAV24*01   TRAJ49*01
# 5909        4115  TRA     CVVNIYDFGNEKLTF  TRAV12-1*01   TRAJ48*01
# 5910        4116  TRA        CAARANNARLMF  TRAV13-1*01   TRAJ31*01
# 5911        4117  TRA         CATNTGNQFYF    TRAV24*01   TRAJ49*01
# 5912        4118  TRA        CAVTPDGQKLLF   TRAV1-1*01         NaN
# 5913        4119  TRA      CAGPMKTSYDKVIF    TRAV35*01   TRAJ50*01
# 5914        4120  TRA      CAGGGSSNTGKLIF   TRAV8-3*01   TRAJ37*01
# 5915        4121  TRA        CALNQAGTALIF   TRAV8-3*01   TRAJ15*01
# 5916        4122  TRA      CAGGGSSNTGKLIF   TRAV8-3*01   TRAJ37*01
# 5917        4123  TRA      CAGPIPPGNEKLTF    TRAV35*01   TRAJ48*01
# 5918        4124  TRA      CAGPIPPGNEKLTF    TRAV35*01   TRAJ48*01
# 5919        4125  TRA        CATDATSDKLIF    TRAV17*01   TRAJ34*01
# 5920        4126  TRA        CATDATSDKLIF    TRAV17*01   TRAJ34*01
# 5921        4127  TRA        CAVRGTNARLMF     TRAV3*01   TRAJ31*01
# 5922        4128  TRA         CARNTGNQFYF    TRAV24*01   TRAJ49*01
# 5923        4129  TRA         CARNTGNQFYF    TRAV24*01   TRAJ49*01
# 5924        4130  TRA      CAMTGTTNAGKSTF  TRAV12-3*01   TRAJ27*01
# 5925        4131  TRA        CAVRDTNARLMF     TRAV3*01   TRAJ31*01
# 5926        4132  TRA        CAVRDTNARLMF     TRAV3*01   TRAJ31*01
# 5927        4133  TRA         CIRDNNNDMRF  TRAV26-2*01   TRAJ43*01
# 5928        4134  TRA         CIIDNNNDMRF  TRAV26-2*01   TRAJ43*01
# 5929        4135  TRA       CAETPTNDYKLSF     TRAV5*01   TRAJ20*01
# 5930        4136  TRA            SSGNQFYF    TRAV21*01   TRAJ49*01
# 5931        4137  TRA         CADYYGQNFVF     TRAV3*01   TRAJ26*01
# 5932        4138  TRA         CASPTGNQFYF    TRAV24*01   TRAJ49*01
# 5933        4139  TRA       CAEIPSNDYKLSF     TRAV5*01   TRAJ20*01
# 5934        4140  TRA         CASGSQGNLIF     TRAV3*01   TRAJ42*01
# 5935        4141  TRA      CAGLTTDSWGKFQF    TRAV25*01   TRAJ24*01
# 5936        4142  TRA        CATYLTGNQFYF  TRAV12-3*01   TRAJ49*01
# 5937        4143  TRA         CAVCNFNKFYF    TRAV24*01   TRAJ21*01
#
#           Species              MHC A MHC B MHC class    Epitope Epitope gene  \
# 0     HomoSapiens        HLA-A*02:01   B2M      MHCI  YILEETSVM          IE1
# 1     HomoSapiens        HLA-A*02:01   B2M      MHCI  YILEETSVM          IE1
# 2     HomoSapiens        HLA-A*02:01   B2M      MHCI  YILEETSVM          IE1
# 3     HomoSapiens           HLA-B*18   B2M      MHCI  ELKRKMIYM          IE1
# 4     HomoSapiens           HLA-B*18   B2M      MHCI  ELKRKMIYM          IE1
# 5     HomoSapiens           HLA-B*18   B2M      MHCI  ELKRKMIYM          IE1
# 6     HomoSapiens           HLA-B*18   B2M      MHCI  ELKRKMIYM          IE1
# 7     HomoSapiens           HLA-B*18   B2M      MHCI  ELKRKMIYM          IE1
# 8     HomoSapiens           HLA-B*18   B2M      MHCI  CVETMCNEY          IE1
# 9     HomoSapiens           HLA-B*18   B2M      MHCI  CVETMCNEY          IE1
# 10    HomoSapiens           HLA-B*18   B2M      MHCI  DEEDAIAAY          IE1
# 11    HomoSapiens  HLA-E*01:01:01:03   B2M      MHCI  VMAPRTLIL         UL40
# 12    HomoSapiens     HLA-A*02:01:98   B2M      MHCI  NLVPMVATV          p65
# 13    HomoSapiens    HLA-A*02:01:110   B2M      MHCI  NLVPMVATV          p65
# 14    HomoSapiens     HLA-A*02:01:59   B2M      MHCI  NLVPMVATV          p65
# 15    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 16    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 17    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 18    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 19    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 20    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 21    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 22    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 23    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 24    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 25    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 26    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 27    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 28    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 29    HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# ...           ...                ...   ...       ...        ...          ...
# 5908  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5909  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5910  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5911  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5912  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5913  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5914  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5915  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5916  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5917  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5918  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5919  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5920  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5921  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5922  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5923  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5924  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5925  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5926  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5927  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5928  HomoSapiens        HLA-A*02:01   B2M      MHCI  NLVPMVATV          p65
# 5929  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5930  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5931  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5932  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5933  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5934  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5935  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5936  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
# 5937  HomoSapiens           HLA-A*02   B2M      MHCI  NLVPMVATV          p65
#
#      Epitope species                                          Reference  \
# 0                CMV                                      PMID:10756006
# 1                CMV                                      PMID:10756006
# 2                CMV                                      PMID:10756006
# 3                CMV                                      PMID:10756006
# 4                CMV                                      PMID:10756006
# 5                CMV                                      PMID:10756006
# 6                CMV                                      PMID:10756006
# 7                CMV                                      PMID:10756006
# 8                CMV                                      PMID:10756006
# 9                CMV                                      PMID:10756006
# 10               CMV                                      PMID:10756006
# 11               CMV                                      PMID:16474394
# 12               CMV                                      PMID:19542454
# 13               CMV                                      PMID:26429912
# 14               CMV                                      PMID:26429912
# 15               CMV                                      PMID:25801351
# 16               CMV                                      PMID:25801351
# 17               CMV                                      PMID:25801351
# 18               CMV                                      PMID:25801351
# 19               CMV                                      PMID:25801351
# 20               CMV                                      PMID:25801351
# 21               CMV                                      PMID:25801351
# 22               CMV                                      PMID:25801351
# 23               CMV                                      PMID:25801351
# 24               CMV                                      PMID:25801351
# 25               CMV                                      PMID:25801351
# 26               CMV                                      PMID:25801351
# 27               CMV                                      PMID:25801351
# 28               CMV                                      PMID:25801351
# 29               CMV                                      PMID:25801351
# ...              ...                                                ...
# 5908             CMV                                      PMID:28934479
# 5909             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5910             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5911             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5912             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5913             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5914             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5915             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5916             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5917             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5918             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5919             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5920             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5921             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5922             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5923             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5924             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5925             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5926             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5927             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5928             CMV  https://github.com/antigenomics/vdjdb-db/issue...
# 5929             CMV                                      PMID:28623251
# 5930             CMV                                      PMID:28623251
# 5931             CMV                                      PMID:28623251
# 5932             CMV                                      PMID:28623251
# 5933             CMV                                      PMID:28623251
# 5934             CMV                                      PMID:28623251
# 5935             CMV                                      PMID:28623251
# 5936             CMV                                      PMID:28623251
# 5937             CMV                                      PMID:28623251
#
#                                                  Method  \
# 0     {"frequency": "1/22", "identification": "antig...
# 1     {"frequency": "19/22", "identification": "anti...
# 2     {"frequency": "1/22", "identification": "antig...
# 3     {"frequency": "1/21", "identification": "antig...
# 4     {"frequency": "2/21", "identification": "antig...
# 5     {"frequency": "1/21", "identification": "antig...
# 6     {"frequency": "7/21", "identification": "antig...
# 7     {"frequency": "10/21", "identification": "anti...
# 8     {"frequency": "1/2", "identification": "antige...
# 9     {"frequency": "1/2", "identification": "antige...
# 10    {"frequency": "1/2", "identification": "antige...
# 11    {"frequency": "", "identification": "", "seque...
# 12    {"frequency": "", "identification": "", "seque...
# 13    {"frequency": "", "identification": "", "seque...
# 14    {"frequency": "", "identification": "", "seque...
# 15    {"frequency": "", "identification": "dextramer...
# 16    {"frequency": "", "identification": "dextramer...
# 17    {"frequency": "", "identification": "dextramer...
# 18    {"frequency": "", "identification": "dextramer...
# 19    {"frequency": "", "identification": "dextramer...
# 20    {"frequency": "", "identification": "dextramer...
# 21    {"frequency": "", "identification": "dextramer...
# 22    {"frequency": "", "identification": "dextramer...
# 23    {"frequency": "", "identification": "dextramer...
# 24    {"frequency": "", "identification": "dextramer...
# 25    {"frequency": "", "identification": "dextramer...
# 26    {"frequency": "", "identification": "dextramer...
# 27    {"frequency": "", "identification": "dextramer...
# 28    {"frequency": "", "identification": "dextramer...
# 29    {"frequency": "", "identification": "dextramer...
# ...                                                 ...
# 5908  {"frequency": "2/39", "identification": "tetra...
# 5909  {"frequency": "99%", "identification": "dextra...
# 5910  {"frequency": "67%", "identification": "dextra...
# 5911  {"frequency": "98%", "identification": "pelime...
# 5912  {"frequency": "95%", "identification": "pelime...
# 5913  {"frequency": "1%", "identification": "pelimer...
# 5914  {"frequency": "50%", "identification": "pelime...
# 5915  {"frequency": "20%", "identification": "pelime...
# 5916  {"frequency": "15%", "identification": "pelime...
# 5917  {"frequency": "36%", "identification": "pelime...
# 5918  {"frequency": "3%", "identification": "tetrame...
# 5919  {"frequency": "34%", "identification": "pelime...
# 5920  {"frequency": "82%", "identification": "tetram...
# 5921  {"frequency": "12%", "identification": "pelime...
# 5922  {"frequency": "4%", "identification": "pelimer...
# 5923  {"frequency": "4%", "identification": "tetrame...
# 5924  {"frequency": "3%", "identification": "pelimer...
# 5925  {"frequency": "1%", "identification": "pelimer...
# 5926  {"frequency": "1%", "identification": "tetrame...
# 5927  {"frequency": "0.50%", "identification": "peli...
# 5928  {"frequency": "0.50%", "identification": "peli...
# 5929  {"frequency": "5.1%", "identification": "tetra...
# 5930  {"frequency": "67.5%", "identification": "tetr...
# 5931  {"frequency": "27.4%", "identification": "tetr...
# 5932  {"frequency": "10.3%", "identification": "tetr...
# 5933  {"frequency": "6.9%", "identification": "tetra...
# 5934  {"frequency": "6.9%", "identification": "tetra...
# 5935  {"frequency": "3.45%", "identification": "tetr...
# 5936  {"frequency": "55.2%", "identification": "tetr...
# 5937  {"frequency": "17.2%", "identification": "tetr...
#
#                                                    Meta  \
# 0     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 6     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 7     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 8     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 9     {"cell.subset": "CD8+", "clone.id": "", "donor...
# 10    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 11    {"cell.subset": "", "clone.id": "", "donor.MHC...
# 12    {"cell.subset": "", "clone.id": "", "donor.MHC...
# 13    {"cell.subset": "", "clone.id": "", "donor.MHC...
# 14    {"cell.subset": "", "clone.id": "", "donor.MHC...
# 15    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 16    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 17    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 18    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 19    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 20    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 21    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 22    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 23    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 24    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 25    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 26    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 27    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 28    {"cell.subset": "CD8+", "clone.id": "", "donor...
# 29    {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                 ...
# 5908  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 5909  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5910  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5911  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5912  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5913  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5914  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5915  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5916  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5917  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5918  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5919  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5920  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5921  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5922  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5923  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5924  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5925  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5926  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5927  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5928  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5929  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5930  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5931  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5932  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5933  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5934  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5935  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5936  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5937  {"cell.subset": "CD8+", "clone.id": "", "donor...
#
#                                                 CDR3fix  Score
# 0     {"cdr3": "CASSVDGTGGALGNTIYF", "cdr3_old": "CA...      0
# 1     {"cdr3": "CAWSWGDSTNSPLHF", "cdr3_old": "CAWSW...      1
# 2     {"cdr3": "CASSLVGGTGSVSYQFF", "cdr3_old": "CAS...      0
# 3     {"cdr3": "CASSLLMATNEKLFF", "cdr3_old": "CASSL...      0
# 4     {"cdr3": "CASSYRANYEQYF", "cdr3_old": "CASSYRA...      0
# 5     {"cdr3": "CASSQAVASGGGRSEQFF", "cdr3_old": "CA...      0
# 6     {"cdr3": "CASVTGSTDTQYF", "cdr3_old": "CASVTGS...      0
# 7     {"cdr3": "CASSDGTAYEQYF", "cdr3_old": "CASSDGT...      0
# 8     {"cdr3": "CASSLARNQPQHF", "cdr3_old": "CASSLAR...      1
# 9     {"cdr3": "CASGGADMKTEAFF", "cdr3_old": "CASGGA...      1
# 10    {"cdr3": "CASSPGGGKETQYF", "cdr3_old": "CASSPG...      1
# 11    {"cdr3": "CASSQDRDTQYF", "cdr3_old": "CASSQDRD...      3
# 12    {"cdr3": "CASSPVTGGIYGYTF", "cdr3_old": "CASSP...      3
# 13    {"cdr3": "CASSQTQLWETQYF", "cdr3_old": "CASSQT...      3
# 14    {"cdr3": "CASSLAPGTTNEKLFF", "cdr3_old": "CASS...      3
# 15    {"cdr3": "CASSLFGGGTEAFF", "cdr3_old": "CASSLF...      0
# 16    {"cdr3": "CASSPTGGGTGELFF", "cdr3_old": "CASSP...      0
# 17    {"cdr3": "CASSLGGGSYEQYF", "cdr3_old": "CASSLG...      0
# 18    {"cdr3": "CASSLGGGSYEQYF", "cdr3_old": "CASSLG...      0
# 19    {"cdr3": "CASSLGGGGFYEQYF", "cdr3_old": "CASSL...      0
# 20    {"cdr3": "CASSYGGGEDYGYTF", "cdr3_old": "CASSY...      1
# 21    {"cdr3": "CSGGTGELFF", "cdr3_old": "CSGGTGELF"...      0
# 22    {"cdr3": "CSVGGTLDTQYF", "cdr3_old": "CSVGGTLD...      1
# 23    {"cdr3": "CASRDQTAYYGYTF", "cdr3_old": "CASRDQ...      0
# 24    {"cdr3": "CASSYQTGAAYGYTF", "cdr3_old": "CASSY...      3
# 25    {"cdr3": "CASSYQTGAIYGYTF", "cdr3_old": "CASSY...      0
# 26    {"cdr3": "CASSYQTGTIYGYTF", "cdr3_old": "CASSY...      1
# 27    {"cdr3": "CASSYQTGAAYGYTF", "cdr3_old": "CASSY...      3
# 28    {"cdr3": "CASSCQTGAACGYTF", "cdr3_old": "CASSC...      2
# 29    {"cdr3": "CASSLQTGVRSYEQYF", "cdr3_old": "CASS...      0
# ...                                                 ...    ...
# 5908  {"cdr3": "CASNTGNQFYF", "cdr3_old": "CASNTGNQF...      1
# 5909  {"cdr3": "CVVNIYDFGNEKLTF", "cdr3_old": "CVVNI...      1
# 5910  {"cdr3": "CAARANNARLMF", "cdr3_old": "CAARANNA...      1
# 5911  {"cdr3": "CATNTGNQFYF", "cdr3_old": "CATNTGNQF...      1
# 5912  {"cdr3": "CAVTPDGQKLLF", "cdr3_old": "CAVTPDGQ...      1
# 5913  {"cdr3": "CAGPMKTSYDKVIF", "cdr3_old": "CAGPMK...      0
# 5914  {"cdr3": "CAGGGSSNTGKLIF", "cdr3_old": "CAGGGS...      1
# 5915  {"cdr3": "CALNQAGTALIF", "cdr3_old": "CALNQAGT...      1
# 5916  {"cdr3": "CAGGGSSNTGKLIF", "cdr3_old": "CAGGGS...      1
# 5917  {"cdr3": "CAGPIPPGNEKLTF", "cdr3_old": "CAGPIP...      1
# 5918  {"cdr3": "CAGPIPPGNEKLTF", "cdr3_old": "CAGPIP...      1
# 5919  {"cdr3": "CATDATSDKLIF", "cdr3_old": "CATDATSD...      1
# 5920  {"cdr3": "CATDATSDKLIF", "cdr3_old": "CATDATSD...      1
# 5921  {"cdr3": "CAVRGTNARLMF", "cdr3_old": "CAVRGTNA...      1
# 5922  {"cdr3": "CARNTGNQFYF", "cdr3_old": "CARNTGNQF...      0
# 5923  {"cdr3": "CARNTGNQFYF", "cdr3_old": "CARNTGNQF...      0
# 5924  {"cdr3": "CAMTGTTNAGKSTF", "cdr3_old": "CAMTGT...      0
# 5925  {"cdr3": "CAVRDTNARLMF", "cdr3_old": "CAVRDTNA...      0
# 5926  {"cdr3": "CAVRDTNARLMF", "cdr3_old": "CAVRDTNA...      0
# 5927  {"cdr3": "CIRDNNNDMRF", "cdr3_old": "CIRDNNNDM...      0
# 5928  {"cdr3": "CIIDNNNDMRF", "cdr3_old": "CIIDNNNDM...      0
# 5929  {"cdr3": "CAETPTNDYKLSF", "cdr3_old": "CAETPTN...      3
# 5930  {"cdr3": "SSGNQFYF", "cdr3_old": "SSGNQFYF", "...      3
# 5931  {"cdr3": "CADYYGQNFVF", "cdr3_old": "CADYYGQNF...      3
# 5932  {"cdr3": "CASPTGNQFYF", "cdr3_old": "CASPTGNQF...      3
# 5933  {"cdr3": "CAEIPSNDYKLSF", "cdr3_old": "CAEIPSN...      3
# 5934  {"cdr3": "CASGSQGNLIF", "cdr3_old": "CASGSQGNL...      3
# 5935  {"cdr3": "CAGLTTDSWGKFQF", "cdr3_old": "CAGLTT...      2
# 5936  {"cdr3": "CATYLTGNQFYF", "cdr3_old": "CATYLTGN...      3
# 5937  {"cdr3": "CAVCNFNKFYF", "cdr3_old": "CAVCNFNKF...      3
#
# [5938 rows x 17 columns]

# %%
df_cmv_associated = pd.read_csv('aryuna/cmv_assotiated_164.csv')
print(df_cmv_associated)
# Out:
#             V gene               CDR3         J gene  \
# 0       TCRBV09-01      CASSGQGAYEQYF  TCRBJ02-07*01
# 1       TCRBV19-01    CASSIGPLEHNEQFF  TCRBJ02-01*01
# 2    TCRBV05-01*01    CASSPDRVGQETQYF  TCRBJ02-05*01
# 3    TCRBV07-02*01      CASSLEAEYEQYF  TCRBJ02-07*01
# 4    TCRBV28-01*01      CASSIEGNQPQHF  TCRBJ01-05*01
# 5          TCRBV24        CATSDGDEQFF  TCRBJ02-01*01
# 6    TCRBV05-06*01    CASSLVAGGRETQYF  TCRBJ02-05*01
# 7    TCRBV07-06*01      CASSRGRQETQYF  TCRBJ02-05*01
# 8       TCRBV09-01    CASSAGQGVTYEQYF  TCRBJ02-07*01
# 9    TCRBV14-01*01     CASSQNRGQETQYF  TCRBJ02-05*01
# 10   TCRBV04-03*01      CASSPQRNTEAFF  TCRBJ01-01*01
# 11   TCRBV07-06*01   CASSLAPGATNEKLFF  TCRBJ01-04*01
# 12      TCRBV07-09   CASSLIGVSSYNEQFF  TCRBJ02-01*01
# 13   TCRBV29-01*01      CSVRDNFNQPQHF  TCRBJ01-05*01
# 14         TCRBV12    CASSQTGGRNQPQHF  TCRBJ01-05*01
# 15   TCRBV05-01*01    CASSLVIGGDTEAFF  TCRBJ01-01*01
# 16   TCRBV05-06*01       CASSLRREKLFF  TCRBJ01-04*01
# 17   TCRBV05-06*01     CASSFHGFNQPQHF  TCRBJ01-05*01
# 18   TCRBV15-01*01    CATSRDTQGSYGYTF  TCRBJ01-02*01
# 19   TCRBV07-03*01    CASSRLAGGTDTQYF  TCRBJ02-03*01
# 20      TCRBV07-09    CASSFPTSGQETQYF  TCRBJ02-05*01
# 21   TCRBV25-01*01        CASSPGDEQYF  TCRBJ02-07*01
# 22   TCRBV28-01*01    CASSLPSGLTDTQYF  TCRBJ02-03*01
# 23      TCRBV06-04      CASSEIPNTEAFF  TCRBJ01-01*01
# 24      TCRBV19-01     CASSIWGLDTEAFF  TCRBJ01-01*01
# 25   TCRBV25-01*01        CASSPGDEQFF  TCRBJ02-01*01
# 26   TCRBV15-01*01    CATSRDSQGSYGYTF  TCRBJ01-02*01
# 27   TCRBV06-05*01    CASSYGGLGSYEQYF  TCRBJ02-07*01
# 28   TCRBV05-06*01      CASSPSTGTEAFF  TCRBJ01-01*01
# 29   TCRBV29-01*01     CSVEEDEGIYGYTF  TCRBJ01-02*01
# ..             ...                ...            ...
# 134  TCRBV02-01*01     CASSVETGGTEAFF  TCRBJ01-01*01
# 135        TCRBV12       CASASANYGYTF  TCRBJ01-02*01
# 136  TCRBV11-03*01     CASSSRTGEETQYF  TCRBJ02-05*01
# 137  TCRBV05-06*01     CASSLGRGYEKLFF  TCRBJ01-04*01
# 138  TCRBV06-01*01        CASSGLNEQFF  TCRBJ02-01*01
# 139  TCRBV14-01*01     CASSRNRAQETQYF  TCRBJ02-05*01
# 140  TCRBV25-01*01        CASTPGDEQFF  TCRBJ02-01*01
# 141  TCRBV05-04*01       CASSLGIDTQYF  TCRBJ02-03*01
# 142     TCRBV19-01     CASSIRTNYYGYTF  TCRBJ01-02*01
# 143  TCRBV28-01*01       CASSPISNEQFF  TCRBJ02-01*01
# 144  TCRBV14-01*01     CASSQNRAQETQYF  TCRBJ02-05*01
# 145     TCRBV09-01   CASSALGGAGTGELFF  TCRBJ02-02*01
# 146     TCRBV07-09    CASSLAVLPTDTQYF  TCRBJ02-03*01
# 147  TCRBV07-02*01     CASSLQAGANEQFF  TCRBJ02-01*01
# 148     TCRBV19-01      CASSTGGAQPQHF  TCRBJ01-05*01
# 149     TCRBV07-09  CASSLGASGSRTDTQYF  TCRBJ02-03*01
# 150     TCRBV19-01    CASSRGTGATDTQYF  TCRBJ02-03*01
# 151     TCRBV06-06       CASSYPGETQYF  TCRBJ02-05*01
# 152  TCRBV11-02*02      CASSLTDTGELFF  TCRBJ02-02*01
# 153  TCRBV28-01*01      CASRPQGNYGYTF  TCRBJ01-02*01
# 154  TCRBV06-05*01       CASSTSGNTIYF  TCRBJ01-03*01
# 155  TCRBV05-01*01      CASSSGTGDEQYF  TCRBJ02-07*01
# 156  TCRBV18-01*01    CASSPPAGTNYGYTF  TCRBJ01-02*01
# 157  TCRBV18-01*01     CASSPLGGTTEAFF  TCRBJ01-01*01
# 158  TCRBV05-01*01       CASSLGWTEAFF  TCRBJ01-01*01
# 159  TCRBV15-01*01     CATSREGSGYEQYF  TCRBJ02-07*01
# 160  TCRBV06-05*01       CASSYAGDGYTF  TCRBJ01-02*01
# 161  TCRBV04-01*01     CASSDRGNTGELFF  TCRBJ02-02*01
# 162        TCRBV20       CSARRGPGELFF  TCRBJ02-02*01
# 163        TCRBV03      CASSQGLQETQYF  TCRBJ02-05*01
#
#      Incidence in CMV+ subjects  Incidence in CMV- subjects       P-value  \
# 0                            61                          11  2.160000e-13
# 1                            30                           0  1.750000e-11
# 2                            33                           1  2.660000e-11
# 3                            30                           1  3.200000e-10
# 4                            26                           0  5.310000e-10
# 5                            41                           6  5.870000e-10
# 6                            50                          11  6.100000e-10
# 7                            37                           5  2.560000e-09
# 8                            24                           0  2.880000e-09
# 9                            29                           2  6.650000e-09
# 10                           29                           2  6.650000e-09
# 11                           35                           5  1.120000e-08
# 12                           27                           2  3.190000e-08
# 13                           21                           0  3.590000e-08
# 14                           29                           3  4.180000e-08
# 15                           26                           2  6.940000e-08
# 16                           26                           2  6.940000e-08
# 17                           20                           0  8.290000e-08
# 18                           20                           0  8.290000e-08
# 19                           53                          18  8.550000e-08
# 20                           28                           3  8.880000e-08
# 21                           23                           1  9.440000e-08
# 22                           25                           2  1.500000e-07
# 23                           19                           0  1.910000e-07
# 24                           29                           4  2.030000e-07
# 25                           29                           4  2.030000e-07
# 26                           22                           1  2.100000e-07
# 27                           26                           3  3.940000e-07
# 28                           18                           0  4.390000e-07
# 29                           18                           0  4.390000e-07
# ..                          ...                         ...           ...
# 134                          12                           0  6.210000e-05
# 135                          12                           0  6.210000e-05
# 136                          12                           0  6.210000e-05
# 137                          12                           0  6.210000e-05
# 138                          12                           0  6.210000e-05
# 139                          12                           0  6.210000e-05
# 140                          12                           0  6.210000e-05
# 141                          12                           0  6.210000e-05
# 142                          12                           0  6.210000e-05
# 143                          12                           0  6.210000e-05
# 144                          12                           0  6.210000e-05
# 145                          12                           0  6.210000e-05
# 146                          12                           0  6.210000e-05
# 147                          12                           0  6.210000e-05
# 148                          12                           0  6.210000e-05
# 149                          12                           0  6.210000e-05
# 150                          12                           0  6.210000e-05
# 151                          37                          15  6.880000e-05
# 152                          30                          10  7.390000e-05
# 153                          30                          10  7.390000e-05
# 154                          27                           8  7.610000e-05
# 155                          27                           8  7.610000e-05
# 156                          27                           8  7.610000e-05
# 157                          22                           5  8.760000e-05
# 158                          22                           5  8.760000e-05
# 159                          22                           5  8.760000e-05
# 160                          31                          11  9.350000e-05
# 161                          31                          11  9.350000e-05
# 162                          35                          14  9.800000e-05
# 163                          81                          55  9.970000e-05
#
#     HLA restriction
# 0               NaN
# 1                A1
# 2               NaN
# 3                B8
# 4               NaN
# 5                A1
# 6                B8
# 7               NaN
# 8            A1, B8
# 9               NaN
# 10               B7
# 11               A2
# 12           A3, B7
# 13              NaN
# 14               A2
# 15               B8
# 16              A29
# 17               B8
# 18              NaN
# 19               B8
# 20              A24
# 21               B7
# 22              NaN
# 23              A24
# 24              NaN
# 25               B7
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ..              ...
# 134             NaN
# 135              A2
# 136             NaN
# 137             B62
# 138             NaN
# 139             NaN
# 140              B7
# 141             NaN
# 142             NaN
# 143              B7
# 144             NaN
# 145             NaN
# 146             NaN
# 147             NaN
# 148             NaN
# 149             B45
# 150             NaN
# 151             NaN
# 152             NaN
# 153             NaN
# 154             NaN
# 155             NaN
# 156             NaN
# 157              B8
# 158             NaN
# 159             NaN
# 160             NaN
# 161             NaN
# 162             NaN
# 163             NaN
#
# [164 rows x 7 columns]

# %%
#res_list = [i for i in df_cmv_associated if i in df_sh_cmv]
#print ("The intersection of two lists is : " + str(res_list)) 
type(df_cmv_associated)
# Out:
# pandas.core.frame.DataFrame

# %%
# s1 - set with intersection
#64 cовпадений из 164
s1 = pd.merge(df_cmv_associated,df_sh_cmv, how='inner', on=['CDR3'])
print(s1)
# Out:
#            V gene              CDR3         J gene  \
# 0   TCRBV04-03*01     CASSPQRNTEAFF  TCRBJ01-01*01
# 1   TCRBV04-03*01     CASSPQRNTEAFF  TCRBJ01-01*01
# 2   TCRBV04-03*01     CASSPQRNTEAFF  TCRBJ01-01*01
# 3   TCRBV04-03*01     CASSPQRNTEAFF  TCRBJ01-01*01
# 4   TCRBV04-03*01     CASSPQRNTEAFF  TCRBJ01-01*01
# 5   TCRBV04-03*01     CASSPQRNTEAFF  TCRBJ01-01*01
# 6   TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 7   TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 8   TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 9   TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 10  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 11  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 12  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 13  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 14  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 15  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 16  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 17  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 18  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 19  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 20  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 21  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 22  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 23  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 24  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 25  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 26  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 27  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 28  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# 29  TCRBV07-06*01  CASSLAPGATNEKLFF  TCRBJ01-04*01
# ..            ...               ...            ...
# 34     TCRBV07-09  CASSLIGVSSYNEQFF  TCRBJ02-01*01
# 35     TCRBV07-09  CASSLIGVSSYNEQFF  TCRBJ02-01*01
# 36     TCRBV07-09  CASSLIGVSSYNEQFF  TCRBJ02-01*01
# 37  TCRBV07-03*01   CASSRLAGGTDTQYF  TCRBJ02-03*01
# 38  TCRBV25-01*01       CASSPGDEQFF  TCRBJ02-01*01
# 39  TCRBV15-01*01    CATSRGTVSYEQYF  TCRBJ02-07*01
# 40  TCRBV07-03*01   CASSRLAASTDTQYF  TCRBJ02-03*01
# 41  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 42  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 43  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 44  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 45  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 46  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 47  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 48  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 49  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 50  TCRBV04-03*01     CASSPSRNTEAFF  TCRBJ01-01*01
# 51  TCRBV30-01*01   CAWSVSDLAKNIQYF  TCRBJ02-04*01
# 52  TCRBV04-03*01     CASSPHRNTEAFF  TCRBJ01-01*01
# 53  TCRBV04-03*01     CASSPHRNTEAFF  TCRBJ01-01*01
# 54  TCRBV04-03*01     CASSPHRNTEAFF  TCRBJ01-01*01
# 55  TCRBV04-03*01     CASSPHRNTEAFF  TCRBJ01-01*01
# 56  TCRBV04-03*01     CASSPHRNTEAFF  TCRBJ01-01*01
# 57  TCRBV18-01*01      CASSPTGGELFF  TCRBJ02-02*01
# 58        TCRBV12      CASASANYGYTF  TCRBJ01-02*01
# 59        TCRBV12      CASASANYGYTF  TCRBJ01-02*01
# 60        TCRBV12      CASASANYGYTF  TCRBJ01-02*01
# 61     TCRBV09-01  CASSALGGAGTGELFF  TCRBJ02-02*01
# 62     TCRBV09-01  CASSALGGAGTGELFF  TCRBJ02-02*01
# 63  TCRBV07-02*01    CASSLQAGANEQFF  TCRBJ02-01*01
#
#     Incidence in CMV+ subjects  Incidence in CMV- subjects       P-value  \
# 0                           29                           2  6.650000e-09
# 1                           29                           2  6.650000e-09
# 2                           29                           2  6.650000e-09
# 3                           29                           2  6.650000e-09
# 4                           29                           2  6.650000e-09
# 5                           29                           2  6.650000e-09
# 6                           35                           5  1.120000e-08
# 7                           35                           5  1.120000e-08
# 8                           35                           5  1.120000e-08
# 9                           35                           5  1.120000e-08
# 10                          35                           5  1.120000e-08
# 11                          35                           5  1.120000e-08
# 12                          35                           5  1.120000e-08
# 13                          35                           5  1.120000e-08
# 14                          35                           5  1.120000e-08
# 15                          35                           5  1.120000e-08
# 16                          35                           5  1.120000e-08
# 17                          35                           5  1.120000e-08
# 18                          35                           5  1.120000e-08
# 19                          35                           5  1.120000e-08
# 20                          35                           5  1.120000e-08
# 21                          35                           5  1.120000e-08
# 22                          35                           5  1.120000e-08
# 23                          35                           5  1.120000e-08
# 24                          35                           5  1.120000e-08
# 25                          35                           5  1.120000e-08
# 26                          35                           5  1.120000e-08
# 27                          35                           5  1.120000e-08
# 28                          35                           5  1.120000e-08
# 29                          35                           5  1.120000e-08
# ..                         ...                         ...           ...
# 34                          27                           2  3.190000e-08
# 35                          27                           2  3.190000e-08
# 36                          27                           2  3.190000e-08
# 37                          53                          18  8.550000e-08
# 38                          29                           4  2.030000e-07
# 39                          30                           6  1.420000e-06
# 40                          23                           3  3.530000e-06
# 41                          20                           2  6.610000e-06
# 42                          20                           2  6.610000e-06
# 43                          20                           2  6.610000e-06
# 44                          20                           2  6.610000e-06
# 45                          20                           2  6.610000e-06
# 46                          20                           2  6.610000e-06
# 47                          20                           2  6.610000e-06
# 48                          20                           2  6.610000e-06
# 49                          20                           2  6.610000e-06
# 50                          20                           2  6.610000e-06
# 51                          16                           1  2.310000e-05
# 52                          13                           0  2.730000e-05
# 53                          13                           0  2.730000e-05
# 54                          13                           0  2.730000e-05
# 55                          13                           0  2.730000e-05
# 56                          13                           0  2.730000e-05
# 57                          12                           0  6.210000e-05
# 58                          12                           0  6.210000e-05
# 59                          12                           0  6.210000e-05
# 60                          12                           0  6.210000e-05
# 61                          12                           0  6.210000e-05
# 62                          12                           0  6.210000e-05
# 63                          12                           0  6.210000e-05
#
#    HLA restriction  complex.id Gene            V  ...  MHC B MHC class  \
# 0               B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 1               B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 2               B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 3               B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 4               B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 5               B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 6               A2           0  TRB   TRBV7-9*01  ...    B2M      MHCI
# 7               A2        3386  TRB   TRBV6-1*01  ...    B2M      MHCI
# 8               A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 9               A2           0  TRB   TRBV7-8*01  ...    B2M      MHCI
# 10              A2           0  TRB   TRBV7-8*01  ...    B2M      MHCI
# 11              A2           0  TRB  TRBV11-1*01  ...    B2M      MHCI
# 12              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 13              A2           0  TRB  TRBV11-1*01  ...    B2M      MHCI
# 14              A2           0  TRB   TRBV7-9*01  ...    B2M      MHCI
# 15              A2        3444  TRB   TRBV7-6*01  ...    B2M      MHCI
# 16              A2        3446  TRB   TRBV7-6*01  ...    B2M      MHCI
# 17              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 18              A2        3483  TRB   TRBV7-6*01  ...    B2M      MHCI
# 19              A2        3484  TRB   TRBV7-6*01  ...    B2M      MHCI
# 20              A2        3617  TRB   TRBV7-6*01  ...    B2M      MHCI
# 21              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 22              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 23              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 24              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 25              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 26              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 27              A2        4134  TRB   TRBV7-6*01  ...    B2M      MHCI
# 28              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# 29              A2           0  TRB   TRBV7-6*01  ...    B2M      MHCI
# ..             ...         ...  ...          ...  ...    ...       ...
# 34          A3, B7        3471  TRB   TRBV6-4*01  ...    B2M      MHCI
# 35          A3, B7           0  TRB   TRBV7-9*01  ...    B2M      MHCI
# 36          A3, B7           0  TRB   TRBV7-9*01  ...    B2M      MHCI
# 37              B8         606  TRB   TRBV7-3*01  ...    B2M      MHCI
# 38              B7           0  TRB  TRBV12-3*01  ...    B2M      MHCI
# 39             NaN           0  TRB    TRBV15*01  ...    B2M      MHCI
# 40              B8         607  TRB   TRBV7-3*01  ...    B2M      MHCI
# 41              B7           0  TRB   TRBV7-2*01  ...    B2M      MHCI
# 42              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 43              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 44              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 45              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 46              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 47              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 48              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 49              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 50              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 51             NaN           0  TRB    TRBV30*01  ...    B2M      MHCI
# 52              B7           0  TRB   TRBV7-2*01  ...    B2M      MHCI
# 53              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 54              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 55              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 56              B7           0  TRB   TRBV4-3*01  ...    B2M      MHCI
# 57             NaN           0  TRB   TRBV6-2*01  ...    B2M      MHCI
# 58              A2        1242  TRB  TRBV12-4*01  ...    B2M      MHCI
# 59              A2        1244  TRB  TRBV12-4*01  ...    B2M      MHCI
# 60              A2           0  TRB  TRBV12-4*01  ...    B2M      MHCI
# 61             NaN           0  TRB     TRBV9*01  ...    B2M      MHCI
# 62             NaN           0  TRB     TRBV9*01  ...    B2M      MHCI
# 63             NaN           0  TRB   TRBV7-3*01  ...    B2M      MHCI
#
#         Epitope Epitope gene Epitope species  \
# 0    TPRVTGGGAM          p65             CMV
# 1   RPHERNGFTVL          p65             CMV
# 2   RPHERNGFTVL          p65             CMV
# 3   RPHERNGFTVL          p65             CMV
# 4   RPHERNGFTVL          p65             CMV
# 5   RPHERNGFTVL          p65             CMV
# 6     NLVPMVATV          p65             CMV
# 7     NLVPMVATV          p65             CMV
# 8     NLVPMVATV          p65             CMV
# 9     NLVPMVATV          p65             CMV
# 10    NLVPMVATV          p65             CMV
# 11    NLVPMVATV          p65             CMV
# 12    NLVPMVATV          p65             CMV
# 13    NLVPMVATV          p65             CMV
# 14    NLVPMVATV          p65             CMV
# 15    NLVPMVATV          p65             CMV
# 16    NLVPMVATV          p65             CMV
# 17    NLVPMVATV          p65             CMV
# 18    NLVPMVATV          p65             CMV
# 19    NLVPMVATV          p65             CMV
# 20    NLVPMVATV          p65             CMV
# 21    NLVPMVATV          p65             CMV
# 22    NLVPMVATV          p65             CMV
# 23    NLVPMVATV          p65             CMV
# 24    NLVPMVATV          p65             CMV
# 25    NLVPMVATV          p65             CMV
# 26    NLVPMVATV          p65             CMV
# 27    NLVPMVATV          p65             CMV
# 28    NLVPMVATV          p65             CMV
# 29    NLVPMVATV          p65             CMV
# ..          ...          ...             ...
# 34   TPRVTGGGAM          p65             CMV
# 35   TPRVTGGGAM          p65             CMV
# 36   TPRVTGGGAM          p65             CMV
# 37    QIKVRVDMV          IE1             CMV
# 38    NLVPMVATV          p65             CMV
# 39    NLVPMVATV          p65             CMV
# 40    QIKVRVDMV          IE1             CMV
# 41   RPHERNGFTV          p65             CMV
# 42   TPRVTGGGAM          p65             CMV
# 43   TPRVTGGGAM          p65             CMV
# 44  RPHERNGFTVL          p65             CMV
# 45  RPHERNGFTVL          p65             CMV
# 46  RPHERNGFTVL          p65             CMV
# 47  RPHERNGFTVL          p65             CMV
# 48  RPHERNGFTVL          p65             CMV
# 49  RPHERNGFTVL          p65             CMV
# 50  RPHERNGFTVL          p65             CMV
# 51    NLVPMVATV          p65             CMV
# 52   RPHERNGFTV          p65             CMV
# 53   TPRVTGGGAM          p65             CMV
# 54  RPHERNGFTVL          p65             CMV
# 55  RPHERNGFTVL          p65             CMV
# 56  RPHERNGFTVL          p65             CMV
# 57    IPSINVHHY          p65             CMV
# 58    NLVPMVATV          p65             CMV
# 59    NLVPMVATV          p65             CMV
# 60    NLVPMVATV          p65             CMV
# 61    NLVPMVATV          p65             CMV
# 62    NLVPMVATV          p65             CMV
# 63    NLVPMVATV          p65             CMV
#
#                                             Reference  \
# 0                                       PMID:28636589
# 1                                       PMID:22323539
# 2                                       PMID:22323539
# 3                                       PMID:22323539
# 4                                       PMID:22323539
# 5                                       PMID:22323539
# 6                                       PMID:21555537
# 7                                       PMID:16237109
# 8                                       PMID:28423320
# 9                                       PMID:28423320
# 10                                      PMID:28423320
# 11                                      PMID:28423320
# 12                                      PMID:28423320
# 13                                      PMID:28423320
# 14                                      PMID:28423320
# 15                                      PMID:28423320
# 16                                      PMID:28423320
# 17                                      PMID:19017975
# 18                                      PMID:28636589
# 19                                      PMID:28636589
# 20                                      PMID:28636589
# 21                                      PMID:23267020
# 22                                      PMID:19017975
# 23                                      PMID:19017975
# 24                                      PMID:19017975
# 25                                      PMID:21135165
# 26                                      PMID:21135165
# 27  https://github.com/antigenomics/vdjdb-db/issue...
# 28  https://github.com/antigenomics/vdjdb-db/issue...
# 29  https://github.com/antigenomics/vdjdb-db/issue...
# ..                                                ...
# 34                                       PMID:9971792
# 35                                      PMID:28636589
# 36                                      PMID:23267020
# 37                                      PMID:23637823
# 38                                      PMID:28423320
# 39                                      PMID:28636589
# 40                                      PMID:23637823
# 41                                       PMID:9971792
# 42                                      PMID:28636589
# 43                                      PMID:28636589
# 44                                      PMID:22323539
# 45                                      PMID:22323539
# 46                                      PMID:22323539
# 47                                      PMID:22323539
# 48                                      PMID:22323539
# 49                                      PMID:22323539
# 50                                      PMID:22323539
# 51                                      PMID:28423320
# 52                                       PMID:9971792
# 53                                      PMID:28636589
# 54                                      PMID:22323539
# 55                                      PMID:22323539
# 56                                      PMID:22323539
# 57                                      PMID:23028307
# 58                                      PMID:28636592
# 59                                      PMID:28636592
# 60                                      PMID:19017975
# 61                                      PMID:24711416
# 62                                      PMID:28423320
# 63                                      PMID:11756174
#
#                                                Method  \
# 0   {"frequency": "0.04", "identification": "tetra...
# 1   {"frequency": "4/11", "identification": "antig...
# 2   {"frequency": "1/8", "identification": "antige...
# 3   {"frequency": "11/15", "identification": "anti...
# 4   {"frequency": "1/13", "identification": "antig...
# 5   {"frequency": "9/9", "identification": "antige...
# 6   {"frequency": "2/27", "identification": "multi...
# 7   {"frequency": "3/3", "identification": "tetram...
# 8   {"frequency": "14.1523%", "identification": "a...
# 9   {"frequency": "0.0014%", "identification": "an...
# 10  {"frequency": "0.0009%", "identification": "an...
# 11  {"frequency": "0.0007%", "identification": "an...
# 12  {"frequency": "0.0002%", "identification": "an...
# 13  {"frequency": "0.0001%", "identification": "an...
# 14  {"frequency": "0.0001%", "identification": "an...
# 15  {"frequency": "1/5", "identification": "antige...
# 16  {"frequency": "4/4", "identification": "antige...
# 17  {"frequency": "", "identification": "tetramer-...
# 18  {"frequency": "56/184", "identification": "tet...
# 19  {"frequency": "4/184", "identification": "tetr...
# 20  {"frequency": "72/111", "identification": "tet...
# 21  {"frequency": "23/64", "identification": "mult...
# 22  {"frequency": "91/100", "identification": "tet...
# 23  {"frequency": "3/100", "identification": "tetr...
# 24  {"frequency": "1/100", "identification": "cd8n...
# 25  {"frequency": "22%", "identification": "tetram...
# 26  {"frequency": "7%", "identification": "tetrame...
# 27  {"frequency": "0.50%", "identification": "peli...
# 28  {"frequency": "1%", "identification": "pelimer...
# 29  {"frequency": "1%", "identification": "pelimer...
# ..                                                ...
# 34  {"frequency": "1", "identification": "limited-...
# 35  {"frequency": "0.5", "identification": "tetram...
# 36  {"frequency": "16/68", "identification": "mult...
# 37  {"frequency": "", "identification": "multimer-...
# 38  {"frequency": "0.0016%", "identification": "an...
# 39  {"frequency": "1/88", "identification": "tetra...
# 40  {"frequency": "", "identification": "multimer-...
# 41  {"frequency": "1", "identification": "limited-...
# 42  {"frequency": "0.008", "identification": "tetr...
# 43  {"frequency": "0.4", "identification": "tetram...
# 44  {"frequency": "1/10", "identification": "antig...
# 45  {"frequency": "5/10", "identification": "antig...
# 46  {"frequency": "5/9", "identification": "antige...
# 47  {"frequency": "3/8", "identification": "antige...
# 48  {"frequency": "8/8", "identification": "antige...
# 49  {"frequency": "3/15", "identification": "antig...
# 50  {"frequency": "7/9", "identification": "antige...
# 51  {"frequency": "0.4230%", "identification": "an...
# 52  {"frequency": "1", "identification": "limited-...
# 53  {"frequency": "0.004", "identification": "tetr...
# 54  {"frequency": "10/10", "identification": "anti...
# 55  {"frequency": "7/11", "identification": "antig...
# 56  {"frequency": "1/9", "identification": "antige...
# 57  {"frequency": "1/100", "identification": "tetr...
# 58  {"frequency": "2/55", "identification": "tetra...
# 59  {"frequency": "4/24", "identification": "tetra...
# 60  {"frequency": "", "identification": "tetramer-...
# 61  {"frequency": "57/10064", "identification": "t...
# 62  {"frequency": "0.0099%", "identification": "an...
# 63  {"frequency": "", "identification": "tetramer-...
#
#                                                  Meta  \
# 0   {"cell.subset": "", "clone.id": "", "donor.MHC...
# 1   {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2   {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3   {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4   {"cell.subset": "CD8+", "clone.id": "", "donor...
# 5   {"cell.subset": "CD8+", "clone.id": "", "donor...
# 6   {"cell.subset": "CD45RA+CCR7+CD8+", "clone.id"...
# 7   {"cell.subset": "CD8+", "clone.id": "OL-1", "d...
# 8   {"cell.subset": "CD8+", "clone.id": "", "donor...
# 9   {"cell.subset": "CD8+", "clone.id": "", "donor...
# 10  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 11  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 12  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 13  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 14  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 15  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 16  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 17  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 18  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 19  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 20  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 21  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 22  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 23  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 24  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 25  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 26  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 27  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 28  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 29  {"cell.subset": "CD8+", "clone.id": "", "donor...
# ..                                                ...
# 34  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 35  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 36  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 37  {"cell.subset": "CD8+", "clone.id": "3D", "don...
# 38  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 39  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 40  {"cell.subset": "CD8+", "clone.id": "3E", "don...
# 41  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 42  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 43  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 44  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 45  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 46  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 47  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 48  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 49  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 50  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 51  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 52  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 53  {"cell.subset": "", "clone.id": "", "donor.MHC...
# 54  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 55  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 56  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 57  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 58  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 59  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 60  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 61  {"cell.subset": "CD3+CD8+", "clone.id": "", "d...
# 62  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 63  {"cell.subset": "CD8+", "clone.id": "", "donor...
#
#                                               CDR3fix Score
# 0   {"cdr3": "CASSPQRNTEAFF", "cdr3_old": "CASSPQR...     0
# 1   {"cdr3": "CASSPQRNTEAFF", "cdr3_old": "CASSPQR...     1
# 2   {"cdr3": "CASSPQRNTEAFF", "cdr3_old": "CASSPQR...     1
# 3   {"cdr3": "CASSPQRNTEAFF", "cdr3_old": "CASSPQR...     1
# 4   {"cdr3": "CASSPQRNTEAFF", "cdr3_old": "CASSPQR...     1
# 5   {"cdr3": "CASSPQRNTEAFF", "cdr3_old": "CASSPQR...     1
# 6   {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 7   {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 8   {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 9   {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     0
# 10  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     0
# 11  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CSSL...     0
# 12  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 13  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     0
# 14  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     0
# 15  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 16  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 17  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 18  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 19  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     0
# 20  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 21  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 22  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 23  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 24  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 25  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 26  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 27  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     0
# 28  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# 29  {"cdr3": "CASSLAPGATNEKLFF", "cdr3_old": "CASS...     1
# ..                                                ...   ...
# 34  {"cdr3": "CASSLIGVSSYNEQFF", "cdr3_old": "CASS...     3
# 35  {"cdr3": "CASSLIGVSSYNEQFF", "cdr3_old": "CASS...     1
# 36  {"cdr3": "CASSLIGVSSYNEQFF", "cdr3_old": "CASS...     1
# 37  {"cdr3": "CASSRLAGGTDTQYF", "cdr3_old": "CASSR...     1
# 38  {"cdr3": "CASSPGDEQFF", "cdr3_old": "CASSPGDEQ...     0
# 39  {"cdr3": "CATSRGTVSYEQYF", "cdr3_old": "CATSRG...     0
# 40  {"cdr3": "CASSRLAASTDTQYF", "cdr3_old": "CASSR...     1
# 41  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     3
# 42  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 43  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 44  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 45  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 46  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 47  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 48  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 49  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 50  {"cdr3": "CASSPSRNTEAFF", "cdr3_old": "CASSPSR...     1
# 51  {"cdr3": "CAWSVSDLAKNIQYF", "cdr3_old": "CAWSV...     0
# 52  {"cdr3": "CASSPHRNTEAFF", "cdr3_old": "CASSPHR...     3
# 53  {"cdr3": "CASSPHRNTEAFF", "cdr3_old": "CASSPHR...     0
# 54  {"cdr3": "CASSPHRNTEAFF", "cdr3_old": "CASSPHR...     1
# 55  {"cdr3": "CASSPHRNTEAFF", "cdr3_old": "CASSPHR...     1
# 56  {"cdr3": "CASSPHRNTEAFF", "cdr3_old": "CASSPHR...     1
# 57  {"cdr3": "CASSPTGGELFF", "cdr3_old": "CASSPTGG...     0
# 58  {"cdr3": "CASASANYGYTF", "cdr3_old": "CASASANY...     0
# 59  {"cdr3": "CASASANYGYTF", "cdr3_old": "CASASANY...     1
# 60  {"cdr3": "CASASANYGYTF", "cdr3_old": "CASASANY...     0
# 61  {"cdr3": "CASSALGGAGTGELFF", "cdr3_old": "CASS...     0
# 62  {"cdr3": "CASSALGGAGTGELFF", "cdr3_old": "CASS...     0
# 63  {"cdr3": "CASSLQAGANEQFF", "cdr3_old": "CASSLQ...     0
#
# [64 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
venn2([df_cmv_associated,df_sh_cmv])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in <lambda>(x)
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-9a55adb441c1> in <module>
#       2 import matplotlib.pyplot as plt
#       3 from matplotlib_venn import venn2
# ----> 4 venn2([df_cmv_associated,df_sh_cmv])
#       5 plt.show()
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib_venn/_venn2.py in venn2(subsets, set_labels, set_colors, alpha, normalize_to, ax, subset_label_formatter)
#     222         subsets = [subsets.get(t, 0) for t in ['10', '01', '11']]
#     223     elif len(subsets) == 2:
# --> 224         subsets = compute_venn2_subsets(*subsets)
#     225
#     226     if subset_label_formatter is None:
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib_venn/_venn2.py in compute_venn2_subsets(a, b)
#     148         raise ValueError("Both arguments must be of the same type")
#     149     set_size = len if type(a) != Counter else lambda x: sum(x.values())   # We cannot use len to compute the cardinality of a Counter
# --> 150     return (set_size(a - b), set_size(b - a), set_size(a & b))
#     151
#     152
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1548
#    1549         if isinstance(other, ABCDataFrame):  # Another DataFrame
# -> 1550             return self._combine_frame(other, na_op, fill_value, level)
#    1551         elif isinstance(other, ABCSeries):
#    1552             return _combine_series_frame(self, other, na_op,
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value, level)
#    4740                 # unique columns
#    4741                 result = {col: _arith_op(this[col], other[col])
# -> 4742                           for col in this}
#    4743                 result = self._constructor(result, index=new_index,
#    4744                                            columns=new_columns, copy=False)
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/frame.py in <dictcomp>(.0)
#    4740                 # unique columns
#    4741                 result = {col: _arith_op(this[col], other[col])
# -> 4742                           for col in this}
#    4743                 result = self._constructor(result, index=new_index,
#    4744                                            columns=new_columns, copy=False)
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/frame.py in _arith_op(left, right)
#    4733             # left._binop(right, func, fill_value=fill_value)
#    4734             left, right = ops.fill_binop(left, right, fill_value)
# -> 4735             return func(left, right)
#    4736
#    4737         if this._is_mixed_type or other._is_mixed_type:
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1514                 if xrav.size:
#    1515                     with np.errstate(all='ignore'):
# -> 1516                         result[mask] = op(xrav, yrav)
#    1517
#    1518             elif isinstance(x, np.ndarray):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
