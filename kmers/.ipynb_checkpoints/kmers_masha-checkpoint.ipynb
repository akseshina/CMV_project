# %%
import csv
import pandas as pd
from collections import Counter

# %%
vecs = dict()
with open("./kmers/atchley_factors.csv", 'r') as stream:
	for line in stream:
		row = line.split(',')
		key = row[0]
		values = []
		for value in row[1:]:
			values.append(float(value))
		vecs[key] = values
length = len(vecs['A'])
labels = ['I', 'II', 'III', 'IV', 'V']

def features(sequence):
	values = []
	for aa in sequence:
		values += vecs[aa]
	return values

# %%
def load_repertoires(data_dir):
  repertoires = dict()
  with open(data_dir+'HIP0062.csv', 'r') as keyfile_stream:
    keyfile_reader = csv.DictReader(keyfile_stream, delimiter=',')
    for keyfile_row in keyfile_reader:
      sample_id = keyfile_row['amino_acid']
      diagnosis_id = keyfile_row['Diagnosis']
      sequences = dict()
      path = data_dir+'/data/sample_'+keyfile_row['Sample']+'.csv'
      with open(path, 'r') as sample_stream:
        sample_reader = csv.DictReader(sample_stream, delimiter=',')
        for sample_row in sample_reader:
          sequence = sample_row['Sequence']
          count = float(sample_row['Count'])
          if sequence not in sequences:
            sequences[sequence] = count
          else:
            sequences[sequence] += count
      repertoires[sample_id] = {
        'Diagnosis': diagnosis_id,
        'Sequences': sequences
      }
  return repertoires

# %%
def load_repertoires(path):
    sample <- pd.read_csv(path)

# %%
d = pd.read_csv("./kmers/test_sample/HIP00602.tsv")

# %%
cdr3 = d['amino_acid']

# %%
snip_size = 4
cdr3_counts = Counter()

for i in range(len(cdr3)):
    sequence = cdr3[i]
    if '*' not in sequence:
        sequence = sequence[3:(-3)]
        stop = len(sequence)-snip_size+1
        for j in range(stop):
            snip = sequence[j:j+snip_size]
            cdr3_counts[snip] += 1

cdr3_counts = dict(cdr3_counts)

for (snip, count) in cdr3_counts.items():
    print(snip)
    print(features(snip))
    break
#            features()
# Out:
# RSNQ
# [1.538, -0.055, 1.502, 0.44, 2.897, -0.228, 1.399, -4.76, 0.67, -2.647, 0.945, 0.828, 1.299, -0.169, 0.933, 0.931, -0.179, -3.005, -0.503, -1.853]

# %%
dict(cdr3_counts)
# Out:
# {'RSNQ': 143,
#  'SNQP': 3454,
#  'SVYN': 30,
#  'VYNE': 328,
#  'SIGE': 38,
#  'SQPS': 36,
#  'QPSG': 47,
#  'PSGA': 220,
#  'SGAN': 2241,
#  'GANV': 3332,
#  'SRWV': 25,
#  'RWVQ': 20,
#  'WVQG': 24,
#  'VQGN': 63,
#  'QGNT': 411,
#  'GNTE': 1739,
#  'LRDR': 166,
#  'RDRG': 1003,
#  'DRGL': 387,
#  'RGLG': 271,
#  'GLGE': 311,
#  'LGET': 264,
#  'SQVA': 162,
#  'QVAE': 39,
#  'VAES': 37,
#  'AESS': 69,
#  'ESSY': 196,
#  'SSYE': 2187,
#  'SLNN': 45,
#  'LNNL': 28,
#  'NNLN': 27,
#  'NLNT': 68,
#  'LNTE': 1106,
#  'SSLT': 111,
#  'SLTS': 390,
#  'LTSG': 489,
#  'TSGR': 1135,
#  'SGRY': 164,
#  'GRYE': 318,
#  'SLFP': 65,
#  'LFPN': 3,
#  'FPNE': 12,
#  'SKAD': 13,
#  'KADF': 4,
#  'ADFG': 7,
#  'DFGD': 9,
#  'FGDR': 35,
#  'GDRD': 84,
#  'DRDE': 41,
#  'RDEK': 78,
#  'SPTS': 300,
#  'PTSD': 30,
#  'TSDS': 43,
#  'SDSY': 93,
#  'DSYE': 482,
#  'STGT': 433,
#  'TGTS': 437,
#  'GTSS': 253,
#  'TSSE': 34,
#  'SSEK': 34,
#  'SQVG': 355,
#  'QVGT': 69,
#  'VGTT': 36,
#  'GTTD': 166,
#  'TTDT': 377,
#  'INRQ': 3,
#  'NRQT': 4,
#  'RQTE': 17,
#  'SQAM': 25,
#  'QAMS': 22,
#  'AMSS': 26,
#  'MSSY': 46,
#  'SSYN': 1902,
#  'SYNE': 4268,
#  'SPWD': 62,
#  'PWDH': 20,
#  'WDHW': 19,
#  'DHWS': 19,
#  'HWSE': 19,
#  'WSEK': 23,
#  'RVGG': 225,
#  'VGGE': 180,
#  'SQDG': 531,
#  'QDGG': 166,
#  'DGGS': 101,
#  'GGSN': 386,
#  'GSNQ': 650,
#  'IPAP': 12,
#  'PAPG': 50,
#  'APGS': 62,
#  'PGSG': 182,
#  'GSGG': 552,
#  'SGGS': 604,
#  'GGSY': 1004,
#  'GSYE': 1892,
#  'RPKI': 4,
#  'PKIG': 7,
#  'KIGG': 12,
#  'IGGG': 118,
#  'GGGV': 164,
#  'GGVP': 43,
#  'GVPN': 28,
#  'VPNE': 34,
#  'SISD': 18,
#  'ISDS': 14,
#  'SDSP': 110,
#  'DSPP': 8,
#  'SPPT': 165,
#  'PPTD': 35,
#  'PTDT': 483,
#  'SQDW': 248,
#  'QDWV': 13,
#  'DWVI': 5,
#  'WVIQ': 5,
#  'VIQW': 5,
#  'IQWD': 8,
#  'QWDS': 12,
#  'WDSN': 30,
#  'DSNQ': 426,
#  'SFHR': 27,
#  'FHRE': 11,
#  'HREQ': 12,
#  'REQP': 34,
#  'SSTS': 173,
#  'STSP': 29,
#  'TSPM': 6,
#  'SPME': 9,
#  'PMET': 7,
#  'GTGG': 1791,
#  'TGGT': 490,
#  'GGTN': 180,
#  'GTNE': 341,
#  'TNEK': 1543,
#  'SGGT': 684,
#  'GGTS': 381,
#  'GTSA': 134,
#  'TSAW': 18,
#  'SAWD': 34,
#  'AWDT': 24,
#  'WDTE': 92,
#  'SQDL': 608,
#  'QDLG': 173,
#  'DLGA': 44,
#  'LGAY': 38,
#  'GAYS': 65,
#  'AYSG': 42,
#  'YSGN': 177,
#  'SGNT': 3435,
#  'SPGQ': 956,
#  'PGQG': 1804,
#  'GQGY': 498,
#  'QGYN': 151,
#  'GYNS': 183,
#  'YNSP': 1351,
#  'SLQG': 671,
#  'LQGD': 78,
#  'QGDL': 34,
#  'GDLK': 15,
#  'DLKN': 16,
#  'LKNI': 31,
#  'SQSP': 63,
#  'QSPG': 36,
#  'SPGG': 882,
#  'PGGT': 237,
#  'SDGT': 129,
#  'DGTG': 195,
#  'GGTD': 1062,
#  'GTDT': 2897,
#  'SDFK': 10,
#  'DFKR': 6,
#  'FKRG': 11,
#  'KRGQ': 18,
#  'RGQT': 80,
#  'GQTG': 69,
#  'QTGE': 77,
#  'SYDI': 8,
#  'YDIL': 3,
#  'DILV': 4,
#  'ILVP': 3,
#  'LVPD': 16,
#  'VPDR': 17,
#  'PDRH': 5,
#  'DRHH': 7,
#  'RHHS': 4,
#  'HHSY': 6,
#  'HSYE': 154,
#  'NPVD': 9,
#  'PVDR': 23,
#  'VDRV': 39,
#  'DRVG': 192,
#  'RVGE': 141,
#  'VGEK': 108,
#  'SQGR': 362,
#  'QGRD': 117,
#  'GRDS': 123,
#  'RDSG': 240,
#  'DSGG': 221,
#  'SGGG': 935,
#  'GGGE': 804,
#  'GGET': 1026,
#  'SPGT': 1240,
#  'PGTG': 1164,
#  'GTGF': 147,
#  'TGFY': 50,
#  'GFYG': 96,
#  'SGAG': 368,
#  'GAGG': 897,
#  'AGGL': 500,
#  'GGLS': 245,
#  'GLSD': 42,
#  'LSDT': 60,
#  'SLGG': 2142,
#  'LGGG': 739,
#  'GGGS': 612,
#  'GGSV': 76,
#  'GSVD': 47,
#  'SVDT': 81,
#  'VDTG': 81,
#  'DTGE': 964,
#  'PPTM': 15,
#  'PTMN': 18,
#  'TMNT': 78,
#  'MNTE': 1397,
#  'EWTG': 31,
#  'WTGA': 42,
#  'TGAN': 368,
#  'GANY': 253,
#  'ANYG': 782,
#  'SDQG': 71,
#  'DQGL': 25,
#  'QGLN': 123,
#  'GLNQ': 96,
#  'LNQP': 262,
#  'SDVT': 12,
#  'DVTG': 23,
#  'VTGG': 162,
#  'TGGF': 172,
#  'GGFR': 39,
#  'GFRE': 42,
#  'FRET': 40,
#  'SLSQ': 139,
#  'LSQG': 98,
#  'SQGA': 413,
#  'QGAI': 97,
#  'GAIN': 45,
#  'AINY': 16,
#  'INYG': 135,
#  'RSKG': 18,
#  'SKGA': 55,
#  'KGAF': 17,
#  'GAFD': 20,
#  'AFDT': 20,
#  'FDTE': 34,
#  'GLGR': 79,
#  'LGRT': 102,
#  'GRTE': 293,
#  'SAGI': 27,
#  'AGIG': 40,
#  'GIGG': 88,
#  'IGGS': 76,
#  'GGSE': 258,
#  'SRRT': 114,
#  'RRTG': 286,
#  'RTGW': 49,
#  'TGWN': 40,
#  'GWNT': 80,
#  'WNTE': 181,
#  'SAEQ': 21,
#  'AEQG': 24,
#  'EQGM': 15,
#  'QGMN': 76,
#  'GMNT': 349,
#  'MNTG': 81,
#  'NTGE': 4102,
#  'SPWL': 24,
#  'PWLG': 20,
#  'WLGR': 17,
#  'SGRG': 613,
#  'GRGG': 526,
#  'RGGQ': 251,
#  'GGQA': 102,
#  'GQAP': 46,
#  'QAPG': 54,
#  'SLAG': 1992,
#  'LAGN': 297,
#  'AGNE': 270,
#  'SQVS': 129,
#  'QVSG': 99,
#  'VSGK': 14,
#  'SGKP': 13,
#  'GKPT': 6,
#  'KPTG': 25,
#  'PTGE': 282,
#  'SELG': 121,
#  'ELGD': 13,
#  'LGDS': 86,
#  'GDSP': 199,
#  'DSPT': 24,
#  'SPTN': 51,
#  'PTNE': 128,
#  'SQEA': 175,
#  'QEAG': 77,
#  'EAGE': 132,
#  'AGEL': 33,
#  'GELY': 23,
#  'ELYN': 23,
#  'LYNE': 378,
#  'SADG': 59,
#  'ADGT': 45,
#  'GTGA': 600,
#  'TGAY': 218,
#  'GAYE': 947,
#  'SVVT': 26,
#  'VVTG': 47,
#  'VTGW': 11,
#  'GTSG': 2342,
#  'TSGD': 186,
#  'SGDN': 71,
#  'GDNE': 364,
#  'SQGS': 323,
#  'QGSG': 404,
#  'GSGR': 208,
#  'SGRN': 132,
#  'GRNT': 396,
#  'RNTD': 53,
#  'NTDT': 513,
#  'SLDR': 666,
#  'LDRA': 115,
#  'DRAG': 230,
#  'RAGN': 164,
#  'AGNT': 860,
#  'SGDQ': 49,
#  'GDQG': 20,
#  'DQGG': 55,
#  'QGGG': 497,
#  'GGGW': 53,
#  'GGWN': 45,
#  'GWNE': 67,
#  'RPEM': 1,
#  'PEMN': 3,
#  'EMNT': 45,
#  'SDDS': 23,
#  'DDSP': 15,
#  'DSPS': 55,
#  'SPSS': 196,
#  'PSSP': 24,
#  'SQIR': 23,
#  'QIRA': 8,
#  'IRAR': 10,
#  'RARR': 28,
#  'ARRN': 18,
#  'RRNT': 110,
#  'RNTE': 643,
#  'RWGL': 17,
#  'WGLN': 22,
#  'GLNN': 52,
#  'LNNE': 83,
#  'TWGR': 22,
#  'WGRG': 86,
#  'RGGT': 467,
#  'GGTE': 901,
#  'SLPG': 389,
#  'LPGG': 123,
#  'GGTY': 383,
#  'GTYE': 904,
#  'RDST': 96,
#  'DSTG': 61,
#  'STGN': 104,
#  'TGNG': 63,
#  'QDGT': 86,
#  'DGTR': 29,
#  'GTRV': 24,
#  'TRVR': 12,
#  'RVRE': 44,
#  'VREK': 36,
#  'SQDS': 347,
#  'QDSA': 37,
#  'DSAE': 19,
#  'SAEL': 13,
#  'AELN': 14,
#  'ELNY': 13,
#  'LNYE': 69,
#  'TPST': 25,
#  'PSTG': 127,
#  'STGS': 109,
#  'TGSY': 312,
#  'GSYG': 306,
#  'SDLA': 55,
#  'DLAG': 206,
#  'LAGT': 560,
#  'AGTG': 812,
#  'TGFS': 55,
#  'GFSE': 33,
#  'RGTG': 752,
#  'GTGN': 615,
#  'TGNE': 153,
#  'GNEK': 480,
#  'SLMR': 26,
#  'LMRL': 7,
#  'MRLG': 12,
#  'RLGD': 32,
#  'LGDY': 40,
#  'GDYG': 431,
#  'SYKG': 40,
#  'YKGS': 12,
#  'KGSG': 44,
#  'GSGA': 560,
#  'SYSG': 681,
#  'YSGG': 213,
#  'GGVY': 147,
#  'GVYE': 350,
#  'SEAG': 272,
#  'EAGP': 42,
#  'AGPD': 55,
#  'GPDG': 31,
#  'PDGN': 34,
#  'DGNQ': 76,
#  'GNQP': 2053,
#  'SDVA': 22,
#  'DVAG': 39,
#  'VAGG': 530,
#  'AGGP': 1081,
#  'GGPD': 228,
#  'GPDT': 361,
#  'LQGQ': 59,
#  'QGQK': 13,
#  'YKGF': 5,
#  'KGFY': 7,
#  'GFYN': 76,
#  'FYNE': 173,
#  'SGQG': 921,
#  'GQGG': 1028,
#  'QGGS': 296,
#  'GGSG': 780,
#  'RDGG': 140,
#  'DGGG': 133,
#  'GGEE': 147,
#  'GEET': 436,
#  'SLAH': 54,
#  'LAHL': 4,
#  'AHLT': 3,
#  'HLTD': 10,
#  'LTDG': 18,
#  'TDGN': 33,
#  'DGNT': 192,
#  'SDLH': 13,
#  'DLHK': 3,
#  'LHKG': 3,
#  'HKGN': 6,
#  'KGNY': 14,
#  'GNYS': 8,
#  'NYSN': 14,
#  'YSNQ': 646,
#  'RTGE': 516,
#  'TGEG': 142,
#  'GEGN': 104,
#  'EGNY': 31,
#  'GNYE': 281,
#  'QVGA': 35,
#  'VGAA': 52,
#  'GAAT': 76,
#  'AATY': 42,
#  'ATYG': 46,
#  'LTSA': 26,
#  'TSAA': 16,
#  'SAAG': 151,
#  'AAGE': 168,
#  'RDIA': 11,
#  'DIAA': 1,
#  'IAAG': 19,
#  'AAGG': 235,
#  'AGGS': 710,
#  'SESG': 320,
#  'ESGL': 39,
#  'SGLA': 605,
#  'GLAE': 230,
#  'LAEI': 16,
#  'AEIL': 5,
#  'EILL': 4,
#  'ILLR': 2,
#  'LLRY': 7,
#  'LRYN': 16,
#  'RYNE': 313,
#  'SPRL': 199,
#  'PRLA': 187,
#  'RLAE': 66,
#  'LAEY': 41,
#  'AEYN': 44,
#  'EYNE': 176,
#  'TGTG': 923,
#  'GTGP': 261,
#  'TGPN': 105,
#  'GPNE': 225,
#  'PNEK': 205,
#  'SLWE': 36,
#  'LWEL': 11,
#  'WELP': 10,
#  'ELPA': 10,
#  'LPAS': 20,
#  'PAST': 34,
#  'ASTD': 423,
#  'STDT': 3839,
#  'YAAT': 10,
#  'AATS': 18,
#  'ATSG': 192,
#  'TSGG': 1580,
#  'SGGY': 307,
#  'GGYN': 527,
#  'GYNE': 1246,
#  'SYSE': 79,
#  'YSED': 8,
#  'SEDG': 49,
#  'EDGS': 18,
#  'DGSY': 93,
#  'LGGS': 325,
#  'GSGT': 326,
#  'SGTE': 245,
#  'SDSR': 80,
#  'DSRG': 71,
#  'SRGE': 147,
#  'RGEG': 137,
#  'GEGT': 159,
#  'EGTD': 116,
#  'ESGE': 67,
#  'SGEV': 32,
#  'GEVS': 26,
#  'EVSE': 13,
#  'SIRD': 52,
#  'IRDQ': 8,
#  'RDQS': 11,
#  'DQSN': 4,
#  'QSNQ': 70,
#  'SWTG': 177,
#  'WTGL': 25,
#  'TGLA': 318,
#  'GLAK': 139,
#  'LAKN': 370,
#  'AKNI': 1001,
#  'SPRR': 177,
#  'PRRG': 89,
#  'RRGY': 38,
#  'RGYN': 141,
#  'GYNY': 35,
#  'YNYG': 74,
#  'SVGS': 160,
#  'VGSS': 77,
#  'GSSD': 53,
#  'SSDE': 32,
#  'SKQG': 88,
#  'VVNT': 27,
#  'VNTE': 700,
#  'TGGG': 707,
#  'GGGD': 292,
#  'GGDT': 612,
#  'GDTG': 321,
#  'SSGV': 136,
#  'SGVG': 246,
#  'GVGD': 127,
#  'VGDL': 14,
#  'GDLG': 46,
#  'DLGP': 24,
#  'SLES': 146,
#  'LESH': 8,
#  'ESHN': 9,
#  'SHNE': 91,
#  'SESP': 86,
#  'ESPG': 54,
#  'SPGN': 106,
#  'PGNS': 36,
#  'GNSN': 116,
#  'NSNQ': 344,
#  'SSGD': 126,
#  'SGDL': 37,
#  'GDLS': 43,
#  'DLSP': 20,
#  'SQLA': 80,
#  'QLAE': 15,
#  'LAEG': 96,
#  'AEGD': 11,
#  'EGDY': 21,
#  'GDYN': 152,
#  'DYNE': 357,
#  'RGQR': 37,
#  'GQRD': 29,
#  'QRDT': 28,
#  'RDTE': 289,
#  'SYSL': 186,
#  'YSLE': 16,
#  'SLEG': 754,
#  'LEGY': 47,
#  'EGYE': 140,
#  'SQVP': 105,
#  'QVPD': 15,
#  'VPDG': 7,
#  'RDEG': 32,
#  'DEGA': 20,
#  'EGAN': 67,
#  'TQSP': 5,
#  'QSPD': 7,
#  'SPDS': 136,
#  'PDSI': 10,
#  'DSIT': 8,
#  'SITE': 14,
#  'SQAG': 421,
#  'QAGG': 194,
#  'AGGA': 401,
#  'GGAN': 430,
#  'GANS': 94,
#  'ANSP': 148,
#  'SFWN': 10,
#  'FWNS': 10,
#  'WNSP': 48,
#  'SQDM': 61,
#  'QDMT': 8,
#  'DMTG': 7,
#  'MTGR': 15,
#  'TGRT': 117,
#  'GRTD': 378,
#  'RTDT': 932,
#  'SWGR': 82,
#  'GRGL': 165,
#  'RGLS': 139,
#  'GLSE': 62,
#  'SLSA': 201,
#  'LSAG': 100,
#  'SAGT': 375,
#  'AGTY': 139,
#  'SQLG': 126,
#  'QLGT': 38,
#  'LGTS': 308,
#  'TSGL': 159,
#  'SGLG': 165,
#  'GLGS': 170,
#  'LGSE': 53,
#  'SPGE': 189,
#  'PGEP': 20,
#  'GEPQ': 11,
#  'EPQE': 21,
#  'PQET': 438,
#  'SDKT': 6,
#  'DKTS': 5,
#  'KTSG': 107,
#  'TSGS': 1026,
#  'SGSN': 154,
#  'GSNE': 354,
#  'SFGG': 410,
#  'FGGG': 191,
#  'GSNY': 162,
#  'SNYG': 521,
#  'SQRT': 128,
#  'QRTV': 8,
#  'RTVL': 15,
#  'TVLG': 24,
#  'VLGS': 37,
#  'LGSP': 85,
#  'RLPS': 17,
#  'LPSS': 29,
#  'PSSK': 1,
#  'SSKN': 11,
#  'SKNT': 26,
#  'KNTE': 259,
#  'RGGS': 375,
#  'GGSP': 268,
#  'SLVG': 827,
#  'LVGS': 90,
#  'VGSG': 179,
#  'GSGN': 752,
#  'SPRT': 542,
#  'PRTG': 410,
#  'SLRG': 659,
#  'LRGR': 110,
#  'RGRT': 174,
#  'SELD': 22,
#  'ELDS': 9,
#  'LDSS': 45,
#  'DSSG': 155,
#  'SSGA': 567,
#  'KRSY': 7,
#  'RSYE': 465,
#  'SSQQ': 31,
#  'SQQG': 241,
#  'QQGS': 75,
#  'QGSN': 217,
#  'GSNT': 271,
#  'SNTE': 429,
#  'TAFT': 10,
#  'AFTD': 43,
#  'FTDT': 328,
#  'ENTG': 209,
#  'LGGQ': 225,
#  'GGQG': 725,
#  'GQGI': 274,
#  'QGIG': 112,
#  'PGGH': 34,
#  'GGHL': 23,
#  'GHLW': 1,
#  'HLWD': 1,
#  'LWDT': 16,
#  'SPSY': 93,
#  'PSYE': 420,
#  'LDRG': 384,
#  'DRGT': 279,
#  'RGTE': 389,
#  'SVGT': 287,
#  'VGTS': 148,
#  'TSGY': 266,
#  'SGYN': 195,
#  'GQTM': 3,
#  'QTMN': 4,
#  'SKTT': 20,
#  'KTTQ': 3,
#  'TTQG': 29,
#  'TQGD': 25,
#  'QGDQ': 76,
#  'GDQP': 388,
#  'SQVV': 79,
#  'QVVD': 10,
#  'VVDS': 8,
#  'VDSN': 28,
#  'SDRA': 104,
#  'DRAE': 53,
#  'RAET': 70,
#  'AETG': 35,
#  'ETGE': 174,
#  'SKTP': 10,
#  'KTPG': 15,
#  'TPGQ': 169,
#  'GQGQ': 147,
#  'QGQE': 119,
#  'GQET': 1397,
#  'SLLG': 437,
#  'LLGD': 40,
#  'LGDL': 27,
#  'GDLT': 21,
#  'DLTD': 25,
#  'LTDT': 475,
#  'VAGE': 158,
#  'AGEP': 32,
#  'GEPD': 10,
#  'EPDT': 31,
#  'TGLL': 38,
#  'GLLN': 52,
#  'LLNT': 76,
#  'LNTG': 314,
#  'SPRD': 312,
#  'PRDT': 86,
#  'RDTN': 34,
#  'DTNS': 16,
#  'TNSG': 38,
#  'NSGN': 223,
#  'SWGT': 110,
#  'WGTG': 124,
#  'GTGE': 1785,
#  'TGET': 151,
#  'GETD': 66,
#  'ETDT': 160,
#  'SPGA': 270,
#  'PGAG': 244,
#  'AGGH': 172,
#  'GGHE': 154,
#  'SQGP': 266,
#  'QGPG': 173,
#  'GPGE': 365,
#  'PGEK': 52,
#  'SLAR': 418,
#  'LARN': 29,
#  'ARNT': 85,
#  'SAMD': 9,
#  'AMDG': 5,
#  'MDGG': 8,
#  'DGGN': 83,
#  'GGNT': 1132,
#  'SQAP': 109,
#  'QAPD': 15,
#  'APDS': 18,
#  'PDSS': 47,
#  'DSSY': 217,
#  'KGEQ': 9,
#  'GEQG': 27,
#  'EQGH': 8,
#  'QGHQ': 24,
#  'GHQP': 91,
#  'KQGE': 15,
#  'QGEE': 55,
#  'GEEK': 48,
#  'STDR': 98,
#  'TDRD': 24,
#  'DRDS': 81,
#  'GGGG': 908,
#  'GGGT': 778,
#  'GTET': 140,
#  'SPEA': 42,
#  'PEAG': 32,
#  'EAGG': 223,
#  'GPDI': 6,
#  'PQGA': 198,
#  'QGAG': 759,
#  'GAGS': 236,
#  'AGSE': 80,
#  'GSET': 184,
#  'SGGE': 394,
#  'GGEQ': 30,
#  'GEQD': 12,
#  'EQDS': 12,
#  'QDSN': 42,
#  'DSNE': 54,
#  'RQGA': 507,
#  'DLGT': 73,
#  'LGTG': 692,
#  'GTGR': 370,
#  'TGRA': 68,
#  'GRAE': 114,
#  'SASP': 34,
#  'ASPD': 6,
#  'SPDR': 427,
#  'PDRG': 348,
#  'SVEE': 19,
#  'VEEL': 2,
#  'EELA': 9,
#  'ELAA': 15,
#  'LAAS': 105,
#  'AAST': 66,
#  'SLAS': 371,
#  'LAST': 75,
#  'ASTE': 54,
#  'SPSG': 731,
#  'PSGG': 527,
#  'GGTG': 991,
#  'SGTA': 222,
#  'GTAG': 158,
#  'TAGP': 25,
#  'AGPN': 58,
#  'GEGA': 88,
#  'EGAP': 33,
#  'GAPN': 65,
#  'APNE': 50,
#  'SELA': 101,
#  'ELAG': 246,
#  'LAGG': 3446,
#  'GPDE': 55,
#  'SPGV': 156,
#  'PGVY': 24,
#  'SRGL': 264,
#  'RGLA': 542,
#  'GLAG': 3530,
#  'LAGE': 623,
#  'AGET': 438,
#  'GETG': 111,
#  'SRLF': 10,
#  'RLFS': 11,
#  'LFSG': 47,
#  'FSGG': 174,
#  'GGGA': 495,
#  'GGAD': 411,
#  'GADT': 833,
#  'LAEA': 22,
#  'AEAG': 23,
#  'ELGN': 15,
#  'LGNT': 221,
#  'GRGN': 350,
#  'RGNT': 494,
#  'SLDL': 187,
#  'LDLA': 55,
#  'LAGA': 894,
#  'AGAS': 221,
#  'GASY': 391,
#  'ASYE': 574,
#  'SLGL': 752,
#  'LGLA': 653,
#  'SQDI': 102,
#  'QDIS': 15,
#  'DISR': 6,
#  'ISRA': 9,
#  'SRAG': 256,
#  'RAGL': 82,
#  'AGLP': 28,
#  'SQGG': 706,
#  'QGGA': 162,
#  'GGAS': 382,
#  'GAST': 241,
#  'SHGQ': 85,
#  'HGQG': 94,
#  'QGGE': 306,
#  'SPGL': 655,
#  'PGLA': 1023,
#  'GLAP': 95,
#  'LAPS': 58,
#  'APSD': 4,
#  'PSDE': 17,
#  'SKME': 1,
#  'KMEG': 3,
#  'MEGY': 3,
#  'SDSS': 105,
#  'DSSR': 18,
#  'SSRS': 76,
#  'SRSG': 264,
#  'RSGA': 248,
#  'SERD': 44,
#  'ERDT': 34,
#  'RDTG': 238,
#  'ATNP': 9,
#  'TNPD': 6,
#  'NPDG': 15,
#  'PDGD': 17,
#  'DGDR': 32,
#  'GDRP': 35,
#  'LSGL': 81,
#  'GLAV': 180,
#  'LAVY': 47,
#  'AVYE': 75,
#  'GGDH': 18,
#  'GDHT': 21,
#  'DHTD': 18,
#  'HTDT': 264,
#  'SLSR': 255,
#  'LSRT': 36,
#  'SRTT': 60,
#  'RTTE': 41,
#  'SQGQ': 346,
#  'QGQG': 366,
#  'QGGN': 277,
#  'SAFS': 13,
#  'AFSG': 23,
#  'SGGA': 1213,
#  'GGAG': 894,
#  'GAGE': 870,
#  'SDRT': 87,
#  'DRTG': 138,
#  'RTGG': 800,
#  'TGGY': 409,
#  'GGYE': 869,
#  'QLGS': 8,
#  'LGSG': 311,
#  'SNKA': 4,
#  'NKAG': 7,
#  'KAGT': 57,
#  'AGTE': 248,
#  'GTEV': 21,
#  'TEVR': 4,
#  'EVRN': 10,
#  'VRNI': 9,
#  'SPYR': 57,
#  'PYRV': 7,
#  'YRVF': 2,
#  'RVFS': 3,
#  'VFSG': 25,
#  'FSGN': 171,
#  'SQAE': 33,
#  'QAEG': 14,
#  'AEGE': 28,
#  'EGET': 134,
#  'SGDR': 180,
#  'GDRG': 470,
#  'DRGG': 469,
#  'GSGE': 432,
#  'SGTS': 601,
#  'SGST': 317,
#  'GSTD': 948,
#  'SLMY': 7,
#  'LMYS': 4,
#  'MYSN': 6,
#  'RRGD': 69,
#  'RGDR': 150,
#  'DRDT': 92,
#  'SNRR': 16,
#  'NRRT': 8,
#  'RRTS': 134,
#  'RTSN': 36,
#  'TSNT': 67,
#  'RELA': 52,
#  'LAGR': 359,
#  'AGRE': 116,
#  'SPTG': 730,
#  'PTGD': 82,
#  'TGDV': 25,
#  'GDVS': 18,
#  'DVSE': 7,
#  'SFSS': 98,
#  'FSSH': 5,
#  'SSHN': 9,
#  'SQRR': 39,
#  'QRRE': 10,
#  'RREY': 15,
#  'REYG': 41,
#  'SDAG': 65,
#  'DAGQ': 17,
#  'AGQG': 468,
#  'GQGN': 646,
#  'QGNS': 148,
#  'GNSP': 578,
#  'TEQA': 9,
#  'EQAH': 5,
#  'QAHY': 9,
#  'AHYE': 26,
#  'PSSA': 8,
#  'SSAA': 40,
#  'VEPY': 4,
#  'EPYG': 15,
#  'TPWP': 1,
#  'PWPG': 6,
#  ...}

# %%
len(cdr3_counts)
# Out:
# 70199
